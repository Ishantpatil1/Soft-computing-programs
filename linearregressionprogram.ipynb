# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishantpatil1/Soft-computing-programs/blob/main/linearregressionprogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# simple small data (x = experience, y = salary)
X = np.array([1, 2, 3, 4, 5]) .reshape(-1, 1)
Y = np.array([10000, 20000, 30000, 40000, 50000])

# model
model = LinearRegression()
model.fit(X, Y)

# prediction
pred = model.predict(X)

# plot
plt.scatter(X, Y)
plt.plot(X, pred, color='red')
plt.show()
